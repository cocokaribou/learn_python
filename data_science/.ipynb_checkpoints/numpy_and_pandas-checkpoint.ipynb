# %% [markdown]
# ### Numpy

# %%
import numpy as np
a = [1,2,3]
b = np.array(a)

# %%
a, b
# Out:
# ([1, 2, 3], array([1, 2, 3]))

# %%
arr1 = [2,3,4]
arr2 = [5,4,6]

print(np.array([arr1,arr2]))
# Out:
# [[2 3 4]
#  [5 4 6]]

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
## data frame
pd.DataFrame([arr1,arr2], columns = ['a','b','c'], index = ['x','y'])
# Out:
#    a  b  c
# x  2  3  4
# y  5  4  6

# %%
## series
pd.Series(arr1)
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64

# %%
data = pd.read_csv("ecommerce.csv")

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['Yearly Amount Spent'])
## one dimensional series
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(data['Yearly Amount Spent'])
# Out:
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 1 columns]

# %%
pd.DataFrame(np.array([arr1, arr2]))
## numpy to pandas data frame
# Out:
#    0  1  2
# 0  2  3  4
# 1  5  4  6

# %%
np.array(data)
## pandas data frame to numpy array
# Out:
# array([['mstephenson@fernandez.com',
#         '835 Frank Tunnel\nWrightmouth, MI 82180-9605', 'Violet', ...,
#         39.57766801952616, 4.0826206329529615, 587.9510539684005],
#        ['hduke@hotmail.com',
#         '4547 Archer Common\nDiazchester, CA 06566-8576', 'DarkGreen',
#         ..., 37.268958868297744, 2.66403418213262, 392.2049334443264],
#        ['pallen@yahoo.com',
#         '24645 Valerie Unions Suite 582\nCobbborough, DC 99414-7564',
#         'Bisque', ..., 37.110597442120856, 4.104543202376424,
#         487.54750486747207],
#        ...,
#        ['dale88@hotmail.com',
#         '0787 Andrews Ranch Apt. 633\nSouth Chadburgh, TN 56128',
#         'Cornsilk', ..., 38.33257633196044, 4.9582644726186995,
#         551.6201454762477],
#        ['cwilson@hotmail.com',
#         '680 Jennifer Lodge Apt. 808\nBrendachester, TX 05000-5873',
#         'Teal', ..., 36.840085729767004, 2.336484668112853,
#         456.46951006629797],
# ...

# %% [markdown]
# ### indexing column

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data['Yearly Amount Spent']
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
data[['Time on App', 'Yearly Amount Spent']]
## indexing two columns from pandas data frame
## pass the list into param
# Out:
#      Time on App  Yearly Amount Spent
# 0      12.655651           587.951054
# 1      11.109461           392.204933
# 2      11.330278           487.547505
# 3      13.717514           581.852344
# 4      12.795189           599.406092
# ..           ...                  ...
# 495    13.566160           573.847438
# 496    11.695736           529.049004
# 497    11.499409           551.620145
# 498    12.391423           456.469510
# 499    12.418808           497.778642
#
# [500 rows x 2 columns]

# %%
data.drop('Yearly Amount Spent')
## error!
## default param = row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-229eb8c3871b> in <module>
# ----> 1 data.drop('Yearly Amount Spent')
#       2 ## error!
#       3 ## input row into param
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
data.drop(['Yearly Amount Spent','Email'], axis = 1) 
## axis 0 = row axis 1 = column
## inplace : modify data, default value false
# Out:
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...               Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...              Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# ...

# %% [markdown]
# ### indexing row

# %%
df = data.head(5)

# %%
df.index=['a','b','c','d','e']

# %%
df
# Out:
#                            Email  \
# a      mstephenson@fernandez.com
# b              hduke@hotmail.com
# c               pallen@yahoo.com
# d        riverarebecca@gmail.com
# e  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# a       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# b     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# c  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# d   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# e  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# a            34.497268    12.655651        39.577668              4.082621
# b            31.926272    11.109461        37.268959              2.664034
# c            33.000915    11.330278        37.110597              4.104543
# ...

# %%
## indexing row
df.loc['d']
# Out:
# Email                                            riverarebecca@gmail.com
# Address                 1414 David Throughway\nPort Jason, OH 22070-1220
# Avatar                                                       SaddleBrown
# Avg. Session Length                                              34.3056
# Time on App                                                      13.7175
# Time on Website                                                  36.7213
# Length of Membership                                             3.12018
# Yearly Amount Spent                                              581.852
# Name: d, dtype: object

# %%
type(df.loc['d'])
# Out:
# pandas.core.series.Series

# %%
df.loc['a':'d']
# Out:
#                        Email  \
# a  mstephenson@fernandez.com
# b          hduke@hotmail.com
# c           pallen@yahoo.com
# d    riverarebecca@gmail.com
#
#                                              Address       Avatar  \
# a       835 Frank Tunnel\nWrightmouth, MI 82180-9605       Violet
# b     4547 Archer Common\nDiazchester, CA 06566-8576    DarkGreen
# c  24645 Valerie Unions Suite 582\nCobbborough, D...       Bisque
# d   1414 David Throughway\nPort Jason, OH 22070-1220  SaddleBrown
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# a            34.497268    12.655651        39.577668              4.082621
# b            31.926272    11.109461        37.268959              2.664034
# c            33.000915    11.330278        37.110597              4.104543
# d            34.305557    13.717514        36.721283              3.120179
#
#    Yearly Amount Spent
# a           587.951054
# b           392.204933
# c           487.547505
# ...

# %%
## indexing row with row count
df.iloc[4]
# Out:
# Email                                       mstephens@davidson-herman.com
# Address                 14023 Rodriguez Passage\nPort Jacobville, PR 3...
# Avatar                                                   MediumAquaMarine
# Avg. Session Length                                               33.3307
# Time on App                                                       12.7952
# Time on Website                                                   37.5367
# Length of Membership                                              4.44631
# Yearly Amount Spent                                               599.406
# Name: e, dtype: object

# %%
df.iloc[0:3]
# Out:
#                        Email  \
# a  mstephenson@fernandez.com
# b          hduke@hotmail.com
# c           pallen@yahoo.com
#
#                                              Address     Avatar  \
# a       835 Frank Tunnel\nWrightmouth, MI 82180-9605     Violet
# b     4547 Archer Common\nDiazchester, CA 06566-8576  DarkGreen
# c  24645 Valerie Unions Suite 582\nCobbborough, D...     Bisque
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# a            34.497268    12.655651        39.577668              4.082621
# b            31.926272    11.109461        37.268959              2.664034
# c            33.000915    11.330278        37.110597              4.104543
#
#    Yearly Amount Spent
# a           587.951054
# b           392.204933
# c           487.547505
